# %% [markdown]
# # Assignment #1
#
# ## Overview of our assignment
# * Given a face image dataset, namely CelebA, you need to perform classification with it, using an MLP and multiple CNN architectures, and then report the results.
# * We provide three models for classification, such as MLP, VGG, and ResNet-18, which can be used as the base architectures for your assignment.
# * You should use the following three regularization techniques: 1) Dropout, 2) L2 normalization, and 3) L1 normalization, based upon the provided three models, and then report the results with regularization techniques that you will implement.
# * Also, you should apply the following three optimization methods: 1) SGD with Momentum, 2) AdaGrad, and 3) Adam, and then report the obtained results as well.

# %%
import os
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from torchvision import datasets
from torchvision import transforms

import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ## Preparing the CelebA dataset
#
# Note that the ~200,000 CelebA face image dataset is relatively large (~1.3 Gb). The download link provided below was provided by the author on the official CelebA website at http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html.
#
# Download link: https://drive.google.com/drive/folders/0B7EVK8r0v71pWEZsZE9oNnFzTm8
#
# 1) Download and unzip the file `./Img/img_align_celeba.zip`, which contains the images in jpeg format.
#
# 2) Download the `./Anno/list_attr_celeba.txt` file, which contains the class labels.
#
# 3) Download the `./Eval/list_eval_partition.txt` file, which contains  training/validation/test partitioning info.
#
# Please make sure that, all your downloaded files (or unzipped folders) are located inside of the "./data" folder to run below codes.
#
# For example,
# * ./data/list_attr_celeba.txt
# * ./data/list_eval_partition.txt
# * ./data/img_align_celeba/{IMAGE_NAME}.jpg

# %%
df1 = pd.read_csv('./data/list_attr_celeba.txt', sep="\s+", skiprows=1, usecols=['Male'])

# Make 0 (female) & 1 (male) labels instead of -1 & 1
df1.loc[df1['Male'] == -1, 'Male'] = 0
df1.head()
# Out:
#             Male
# 000001.jpg     0
# 000002.jpg     0
# 000003.jpg     1
# 000004.jpg     0
# 000005.jpg     0

# %%
df2 = pd.read_csv('./data/list_eval_partition.txt', sep="\s+", skiprows=0, header=None)
df2.columns = ['Filename', 'Partition']
df2 = df2.set_index('Filename')

df2.head()
# Out:
#             Partition
# Filename
# 000001.jpg          0
# 000002.jpg          0
# 000003.jpg          0
# 000004.jpg          0
# 000005.jpg          0

# %%
df3 = df1.merge(df2, left_index=True, right_index=True)
df3.head()
# Out:
#             Male  Partition
# 000001.jpg     0          0
# 000002.jpg     0          0
# 000003.jpg     1          0
# 000004.jpg     0          0
# 000005.jpg     0          0

# %%
df3.to_csv('./data/celeba-gender-partitions.csv')
df4 = pd.read_csv('./data/celeba-gender-partitions.csv', index_col=0)
df4.head()
# Out:
#             Male  Partition
# 000001.jpg     0          0
# 000002.jpg     0          0
# 000003.jpg     1          0
# 000004.jpg     0          0
# 000005.jpg     0          0

# %%
df4.loc[df4['Partition'] == 0].to_csv('./data/celeba-gender-train.csv')
df4.loc[df4['Partition'] == 1].to_csv('./data/celeba-gender-valid.csv')
df4.loc[df4['Partition'] == 2].to_csv('./data/celeba-gender-test.csv')

# %%
# Print sample image
img = Image.open('./data/img_align_celeba/000001.jpg')
print(np.asarray(img, dtype=np.uint8).shape)
plt.imshow(img);
# Out:
# (218, 178, 3)

# %% [markdown]
# ## Implementing the DataLoader for training, validation, and test

# %%
class CelebaDataset(Dataset):
    """Custom Dataset for loading CelebA face images"""

    def __init__(self, csv_path, img_dir, transform=None):
    
        df = pd.read_csv(csv_path, index_col=0)
        self.img_dir = img_dir
        self.csv_path = csv_path
        self.img_names = df.index.values
        self.y = df['Male'].values
        self.transform = transform

    def __getitem__(self, index):
        img = Image.open(os.path.join(self.img_dir,
                                      self.img_names[index]))
        
        if self.transform is not None:
            img = self.transform(img)
        
        label = self.y[index]
        return img, label

    def __len__(self):
        return self.y.shape[0]

# %%
# Note that transforms.ToTensor()
# already divides pixels by 255. internally

custom_transform = transforms.Compose([transforms.CenterCrop((178, 178)),
                                       transforms.Resize((32, 32)),
                                       #transforms.Grayscale(),                                       
                                       #transforms.Lambda(lambda x: x/255.),
                                       transforms.ToTensor()])

train_dataset = CelebaDataset(csv_path='./data/celeba-gender-train.csv',
                              img_dir='./data/img_align_celeba/',
                              transform=custom_transform)

valid_dataset = CelebaDataset(csv_path='./data/celeba-gender-valid.csv',
                              img_dir='./data/img_align_celeba/',
                              transform=custom_transform)

test_dataset = CelebaDataset(csv_path='./data/celeba-gender-test.csv',
                             img_dir='./data/img_align_celeba/',
                             transform=custom_transform)

BATCH_SIZE=256


train_loader = DataLoader(dataset=train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True,
                          num_workers=6)

valid_loader = DataLoader(dataset=valid_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=False,
                          num_workers=6)

test_loader = DataLoader(dataset=test_dataset,
                         batch_size=BATCH_SIZE,
                         shuffle=False,
                         num_workers=6)

# %%
# Testing dataloader

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.manual_seed(0)

num_epochs = 200
for epoch in range(num_epochs):

    for batch_idx, (x, y) in enumerate(train_loader):
        
        print('Epoch:', epoch+1, end='')
        print(' | Batch index:', batch_idx, end='')
        print(' | Batch size:', y.size()[0])
        
        x = x.to(device)
        y = y.to(device)
        break
# Out:
# Epoch: 1 | Batch index: 0 | Batch size: 256
# Epoch: 2 | Batch index: 0 | Batch size: 256
# Epoch: 3 | Batch index: 0 | Batch size: 256
# Epoch: 4 | Batch index: 0 | Batch size: 256
# Epoch: 5 | Batch index: 0 | Batch size: 256
# Epoch: 6 | Batch index: 0 | Batch size: 256
# Epoch: 7 | Batch index: 0 | Batch size: 256
# Epoch: 8 | Batch index: 0 | Batch size: 256
# Epoch: 9 | Batch index: 0 | Batch size: 256
# Epoch: 10 | Batch index: 0 | Batch size: 256
# Epoch: 11 | Batch index: 0 | Batch size: 256
# Epoch: 12 | Batch index: 0 | Batch size: 256
# Epoch: 13 | Batch index: 0 | Batch size: 256
# Epoch: 14 | Batch index: 0 | Batch size: 256
# Epoch: 15 | Batch index: 0 | Batch size: 256
# Epoch: 16 | Batch index: 0 | Batch size: 256
# Epoch: 17 | Batch index: 0 | Batch size: 256
# Epoch: 18 | Batch index: 0 | Batch size: 256
# Epoch: 19 | Batch index: 0 | Batch size: 256
# Epoch: 20 | Batch index: 0 | Batch size: 256
# Epoch: 21 | Batch index: 0 | Batch size: 256
# Epoch: 22 | Batch index: 0 | Batch size: 256
# Epoch: 23 | Batch index: 0 | Batch size: 256
# Epoch: 24 | Batch index: 0 | Batch size: 256
# Epoch: 25 | Batch index: 0 | Batch size: 256
# Epoch: 26 | Batch index: 0 | Batch size: 256
# Epoch: 27 | Batch index: 0 | Batch size: 256
# Epoch: 28 | Batch index: 0 | Batch size: 256
# Epoch: 29 | Batch index: 0 | Batch size: 256
# Epoch: 30 | Batch index: 0 | Batch size: 256
# Epoch: 31 | Batch index: 0 | Batch size: 256
# Epoch: 32 | Batch index: 0 | Batch size: 256
# Epoch: 33 | Batch index: 0 | Batch size: 256
# Epoch: 34 | Batch index: 0 | Batch size: 256
# Epoch: 35 | Batch index: 0 | Batch size: 256
# Epoch: 36 | Batch index: 0 | Batch size: 256
# Epoch: 37 | Batch index: 0 | Batch size: 256
# Epoch: 38 | Batch index: 0 | Batch size: 256
# Epoch: 39 | Batch index: 0 | Batch size: 256
# Epoch: 40 | Batch index: 0 | Batch size: 256
# Epoch: 41 | Batch index: 0 | Batch size: 256
# Epoch: 42 | Batch index: 0 | Batch size: 256
# Epoch: 43 | Batch index: 0 | Batch size: 256
# Epoch: 44 | Batch index: 0 | Batch size: 256
# Epoch: 45 | Batch index: 0 | Batch size: 256
# Epoch: 46 | Batch index: 0 | Batch size: 256
# Epoch: 47 | Batch index: 0 | Batch size: 256
# Epoch: 48 | Batch index: 0 | Batch size: 256
# Epoch: 49 | Batch index: 0 | Batch size: 256
# Epoch: 50 | Batch index: 0 | Batch size: 256
# Epoch: 51 | Batch index: 0 | Batch size: 256
# Epoch: 52 | Batch index: 0 | Batch size: 256
# Epoch: 53 | Batch index: 0 | Batch size: 256
# Epoch: 54 | Batch index: 0 | Batch size: 256
# Epoch: 55 | Batch index: 0 | Batch size: 256
# Epoch: 56 | Batch index: 0 | Batch size: 256
# Epoch: 57 | Batch index: 0 | Batch size: 256
# Epoch: 58 | Batch index: 0 | Batch size: 256
# Epoch: 59 | Batch index: 0 | Batch size: 256
# Epoch: 60 | Batch index: 0 | Batch size: 256
# Epoch: 61 | Batch index: 0 | Batch size: 256
# Epoch: 62 | Batch index: 0 | Batch size: 256
# Epoch: 63 | Batch index: 0 | Batch size: 256
# Epoch: 64 | Batch index: 0 | Batch size: 256
# Epoch: 65 | Batch index: 0 | Batch size: 256
# Epoch: 66 | Batch index: 0 | Batch size: 256
# Epoch: 67 | Batch index: 0 | Batch size: 256
# Epoch: 68 | Batch index: 0 | Batch size: 256
# Epoch: 69 | Batch index: 0 | Batch size: 256
# Epoch: 70 | Batch index: 0 | Batch size: 256
# Epoch: 71 | Batch index: 0 | Batch size: 256
# Epoch: 72 | Batch index: 0 | Batch size: 256
# Epoch: 73 | Batch index: 0 | Batch size: 256
# Epoch: 74 | Batch index: 0 | Batch size: 256
# Epoch: 75 | Batch index: 0 | Batch size: 256
# Epoch: 76 | Batch index: 0 | Batch size: 256
# Epoch: 77 | Batch index: 0 | Batch size: 256
# Epoch: 78 | Batch index: 0 | Batch size: 256
# Epoch: 79 | Batch index: 0 | Batch size: 256
# Epoch: 80 | Batch index: 0 | Batch size: 256
# Epoch: 81 | Batch index: 0 | Batch size: 256
# Epoch: 82 | Batch index: 0 | Batch size: 256
# Epoch: 83 | Batch index: 0 | Batch size: 256
# Epoch: 84 | Batch index: 0 | Batch size: 256
# Epoch: 85 | Batch index: 0 | Batch size: 256
# Epoch: 86 | Batch index: 0 | Batch size: 256
# Epoch: 87 | Batch index: 0 | Batch size: 256
# Epoch: 88 | Batch index: 0 | Batch size: 256
# Epoch: 89 | Batch index: 0 | Batch size: 256
# Epoch: 90 | Batch index: 0 | Batch size: 256
# Epoch: 91 | Batch index: 0 | Batch size: 256
# Epoch: 92 | Batch index: 0 | Batch size: 256
# Epoch: 93 | Batch index: 0 | Batch size: 256
# Epoch: 94 | Batch index: 0 | Batch size: 256
# Epoch: 95 | Batch index: 0 | Batch size: 256
# Epoch: 96 | Batch index: 0 | Batch size: 256
# Epoch: 97 | Batch index: 0 | Batch size: 256
# Epoch: 98 | Batch index: 0 | Batch size: 256
# Epoch: 99 | Batch index: 0 | Batch size: 256
# Epoch: 100 | Batch index: 0 | Batch size: 256
# Epoch: 101 | Batch index: 0 | Batch size: 256
# Epoch: 102 | Batch index: 0 | Batch size: 256
# Epoch: 103 | Batch index: 0 | Batch size: 256
# Epoch: 104 | Batch index: 0 | Batch size: 256
# Epoch: 105 | Batch index: 0 | Batch size: 256
# Epoch: 106 | Batch index: 0 | Batch size: 256
# Epoch: 107 | Batch index: 0 | Batch size: 256
# Epoch: 108 | Batch index: 0 | Batch size: 256
# Epoch: 109 | Batch index: 0 | Batch size: 256
# Epoch: 110 | Batch index: 0 | Batch size: 256
# Epoch: 111 | Batch index: 0 | Batch size: 256
# Epoch: 112 | Batch index: 0 | Batch size: 256
# Epoch: 113 | Batch index: 0 | Batch size: 256
# Epoch: 114 | Batch index: 0 | Batch size: 256
# Epoch: 115 | Batch index: 0 | Batch size: 256
# Epoch: 116 | Batch index: 0 | Batch size: 256
# Epoch: 117 | Batch index: 0 | Batch size: 256
# Epoch: 118 | Batch index: 0 | Batch size: 256
# Epoch: 119 | Batch index: 0 | Batch size: 256
# Epoch: 120 | Batch index: 0 | Batch size: 256
# Epoch: 121 | Batch index: 0 | Batch size: 256
# Epoch: 122 | Batch index: 0 | Batch size: 256
# Epoch: 123 | Batch index: 0 | Batch size: 256
# Epoch: 124 | Batch index: 0 | Batch size: 256
# Epoch: 125 | Batch index: 0 | Batch size: 256
# Epoch: 126 | Batch index: 0 | Batch size: 256
# Epoch: 127 | Batch index: 0 | Batch size: 256
# Epoch: 128 | Batch index: 0 | Batch size: 256
# Epoch: 129 | Batch index: 0 | Batch size: 256
# Epoch: 130 | Batch index: 0 | Batch size: 256
# Epoch: 131 | Batch index: 0 | Batch size: 256
# Epoch: 132 | Batch index: 0 | Batch size: 256
# Epoch: 133 | Batch index: 0 | Batch size: 256
# Epoch: 134 | Batch index: 0 | Batch size: 256
# Epoch: 135 | Batch index: 0 | Batch size: 256
# Epoch: 136 | Batch index: 0 | Batch size: 256
# Epoch: 137 | Batch index: 0 | Batch size: 256
# Epoch: 138 | Batch index: 0 | Batch size: 256
# Epoch: 139 | Batch index: 0 | Batch size: 256
# Epoch: 140 | Batch index: 0 | Batch size: 256
# Epoch: 141 | Batch index: 0 | Batch size: 256
# Epoch: 142 | Batch index: 0 | Batch size: 256
# Epoch: 143 | Batch index: 0 | Batch size: 256
# Epoch: 144 | Batch index: 0 | Batch size: 256
# Epoch: 145 | Batch index: 0 | Batch size: 256
# Epoch: 146 | Batch index: 0 | Batch size: 256
# Epoch: 147 | Batch index: 0 | Batch size: 256
# Epoch: 148 | Batch index: 0 | Batch size: 256
# Epoch: 149 | Batch index: 0 | Batch size: 256
# Epoch: 150 | Batch index: 0 | Batch size: 256
# Epoch: 151 | Batch index: 0 | Batch size: 256
# Epoch: 152 | Batch index: 0 | Batch size: 256
# Epoch: 153 | Batch index: 0 | Batch size: 256
# Epoch: 154 | Batch index: 0 | Batch size: 256
# Epoch: 155 | Batch index: 0 | Batch size: 256
# Epoch: 156 | Batch index: 0 | Batch size: 256
# Epoch: 157 | Batch index: 0 | Batch size: 256
# Epoch: 158 | Batch index: 0 | Batch size: 256
# Epoch: 159 | Batch index: 0 | Batch size: 256
# Epoch: 160 | Batch index: 0 | Batch size: 256
# Epoch: 161 | Batch index: 0 | Batch size: 256
# Epoch: 162 | Batch index: 0 | Batch size: 256
# Epoch: 163 | Batch index: 0 | Batch size: 256
# Epoch: 164 | Batch index: 0 | Batch size: 256
# Epoch: 165 | Batch index: 0 | Batch size: 256
# Epoch: 166 | Batch index: 0 | Batch size: 256
# Epoch: 167 | Batch index: 0 | Batch size: 256
# Epoch: 168 | Batch index: 0 | Batch size: 256
# Epoch: 169 | Batch index: 0 | Batch size: 256
# Epoch: 170 | Batch index: 0 | Batch size: 256
# Epoch: 171 | Batch index: 0 | Batch size: 256
# Epoch: 172 | Batch index: 0 | Batch size: 256
# Epoch: 173 | Batch index: 0 | Batch size: 256
# Epoch: 174 | Batch index: 0 | Batch size: 256
# Epoch: 175 | Batch index: 0 | Batch size: 256
# Epoch: 176 | Batch index: 0 | Batch size: 256
# Epoch: 177 | Batch index: 0 | Batch size: 256
# Epoch: 178 | Batch index: 0 | Batch size: 256
# Epoch: 179 | Batch index: 0 | Batch size: 256
# Epoch: 180 | Batch index: 0 | Batch size: 256
# Epoch: 181 | Batch index: 0 | Batch size: 256
# Epoch: 182 | Batch index: 0 | Batch size: 256
# Epoch: 183 | Batch index: 0 | Batch size: 256
# Epoch: 184 | Batch index: 0 | Batch size: 256
# Epoch: 185 | Batch index: 0 | Batch size: 256
# Epoch: 186 | Batch index: 0 | Batch size: 256
# Epoch: 187 | Batch index: 0 | Batch size: 256
# Epoch: 188 | Batch index: 0 | Batch size: 256
# Epoch: 189 | Batch index: 0 | Batch size: 256
# Epoch: 190 | Batch index: 0 | Batch size: 256
# Epoch: 191 | Batch index: 0 | Batch size: 256
# Epoch: 192 | Batch index: 0 | Batch size: 256
# Epoch: 193 | Batch index: 0 | Batch size: 256
# Epoch: 194 | Batch index: 0 | Batch size: 256
# Epoch: 195 | Batch index: 0 | Batch size: 256
# Epoch: 196 | Batch index: 0 | Batch size: 256
# Epoch: 197 | Batch index: 0 | Batch size: 256
# Epoch: 198 | Batch index: 0 | Batch size: 256
# Epoch: 199 | Batch index: 0 | Batch size: 256
# Epoch: 200 | Batch index: 0 | Batch size: 256

# %% [markdown]
# ## Implementing models

# %%
# Hyperparameters
random_seed = 42
learning_rate = 0.001
num_epochs = 200

# Architecture
num_features = 32*32
num_classes = 2

# Results
train_accs = []
val_accs = []

# %%
from models import mlp
from models import vgg
from models import resnet
from models import dropout_mlp
from models import dropout_vgg
from models import dropout_resnet

# %%
# You need to specify the model that you want to use in here.

#model = mlp.MLP()                 # For MLP
#model = vgg.VGG16()               # For VGG
model = resnet.ResNet18()         # For ResNet18

model = model.to(device)

# %%
# You need to implement optimizers for this assignment,
# Note that you can directly load the optimizer that you want to use in PyTorch library

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate) #SGD
#optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate) #ADAM
#optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=0.1) #ADAM w L2 norm

# %% [markdown]
# ## Training

# %%
def compute_accuracy(model, data_loader):
    correct_pred, num_examples = 0, 0
    for i, (features, targets) in enumerate(data_loader):
            
        features = features.to(device)
        targets = targets.to(device)

        logits, probas = model(features)
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.size(0)
        correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float()/num_examples * 100
    

start_time = time.time()
for epoch in range(num_epochs):
    
    model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):

        features = features.to(device)
        targets = targets.to(device)
        
        ### FORWARD AND BACK PROP
        logits, probas = model(features)
        cost = F.cross_entropy(logits, targets)
        optimizer.zero_grad()
        
        cost.backward()
        
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
#        ### LOGGING
#        if not batch_idx % 50:
#            print ('Epoch: %03d/%03d | Batch %04d/%04d | Cost: %.4f' 
#                   %(epoch+1, num_epochs, batch_idx, 
#                     len(train_loader), cost))

        

    model.eval()
    with torch.set_grad_enabled(False): # save memory during inference
        train_acc = compute_accuracy(model, train_loader)
        val_acc = compute_accuracy(model, valid_loader)
        train_accs.append(train_acc)
        val_accs.append(val_acc)
        print('Epoch: %03d/%03d |Cost: %.3f%% | Train: %.3f%% | Valid: %.3f%%' % (
              epoch+1, num_epochs, cost, train_acc, val_acc))
        
    print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
    
print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
# Time elapsed: 525.44 min
# Epoch: 199/200 | Train: 100.000% | Valid: 95.646%
# Time elapsed: 528.04 min
# Epoch: 200/200 | Train: 100.000% | Valid: 95.651%
# Time elapsed: 530.65 min
# Total Training Time: 530.65 min

# %% [markdown]
# ## Evaluation

# %%
with torch.set_grad_enabled(False): # save memory during inference
    test_acc = compute_accuracy(model, test_loader)
    print('Test accuracy: %.2f%%' % (test_acc))
# Out:
# Test accuracy: 95.03%

# %%
for batch_idx, (features, targets) in enumerate(test_loader):

    features = features
    targets = targets
    break
    
plt.imshow(np.transpose(features[0], (1, 2, 0)))

# %%
model.eval()
logits, probas = model(features.to(device)[0, None])
print('Probability Female %.2f%%' % (probas[0][0]*100))
# Out:
# Probability Female 100.00%

# %% [markdown]
# ## Visualization
#
# You need to draw training curves of your models, and then insert the curves as well as the final results of your model in your report.

# %%
train_accs_np = []

for a in train_accs :
    train_accs_np.append(a.cpu().numpy().item(0))
    print(a.cpu().numpy().item(0))
# Out:
# 89.46058654785156
# 93.07611846923828
# 92.62825012207031
# 95.4733657836914
# 95.90464782714844
# 96.52146911621094
# 96.61054992675781
# 97.8165512084961
# 97.31338500976562
# 98.78785705566406
# 98.62382507324219
# 99.42617797851562
# 99.62400817871094
# 99.86544799804688
# 99.92320251464844
# 95.44142150878906
# 99.99324035644531
# 99.99630737304688
# 99.99815368652344
# 99.99876403808594
# 99.99938201904297
# 99.99938201904297
# 99.99938201904297
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.9975357055664
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99938201904297
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547
# 99.99999237060547

# %%
val_accs_np = []

for a in val_accs :
    val_accs_np.append(a.cpu().numpy().item(0))
    print(a.cpu().numpy().item(0))
# Out:
# 89.89781951904297
# 93.42628479003906
# 93.00850677490234
# 95.16283416748047
# 95.38933563232422
# 95.45477294921875
# 95.4396743774414
# 95.92791748046875
# 95.23330688476562
# 95.90778350830078
# 95.42457580566406
# 95.82221221923828
# 95.701416015625
# 95.79705047607422
# 95.62591552734375
# 92.49005889892578
# 95.75678253173828
# 95.71147918701172
# 95.81214904785156
# 95.78697967529297
# 95.6762466430664
# 95.57054138183594
# 95.52021026611328
# 95.64604949951172
# 95.66618347167969
# 95.75678253173828
# 95.74671173095703
# 95.69638061523438
# 95.7618179321289
# 95.69134521484375
# 95.69638061523438
# 95.56550598144531
# 95.6762466430664
# 95.54537200927734
# 95.68128204345703
# 95.75678253173828
# 95.74168395996094
# 95.68630981445312
# 95.7618179321289
# 95.75678253173828
# 95.7920150756836
# 95.68128204345703
# 95.7064437866211
# 95.71651458740234
# 95.68128204345703
# 95.73664855957031
# 95.71651458740234
# 95.72657775878906
# 95.71147918701172
# 95.69134521484375
# 95.71147918701172
# 95.83228302001953
# 95.701416015625
# 95.69134521484375
# 95.74671173095703
# 95.6410140991211
# 95.66114807128906
# 95.77691650390625
# 95.58060455322266
# 95.74168395996094
# 95.7064437866211
# 95.71147918701172
# 95.65611267089844
# 95.701416015625
# 95.64604949951172
# 95.6762466430664
# 95.701416015625
